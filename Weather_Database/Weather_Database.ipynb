# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        # Retrieving the data in JSON format
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Converting the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiruvalla
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | jalu
# Processing Record 4 of Set 1 | teodoro sampaio
# Processing Record 5 of Set 1 | bjornevatn
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | visnes
# Processing Record 8 of Set 1 | qeshm
# Processing Record 9 of Set 1 | maragheh
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | sisimiut
# Processing Record 14 of Set 1 | necochea
# Processing Record 15 of Set 1 | trapani
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | kismayo
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 1 | jacareacanga
# Processing Record 22 of Set 1 | ilovka
# Processing Record 23 of Set 1 | coihaique
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | konevo
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | coro
# Processing Record 29 of Set 1 | nouadhibou
# Processing Record 30 of Set 1 | agirish
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | soller
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | caceres
# Processing Record 35 of Set 1 | sao felix do xingu
# Processing Record 36 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | trincomalee
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | port-cartier
# Processing Record 42 of Set 1 | trairi
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | bossembele
# City not found. Skipping...
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | skagen
# Processing Record 47 of Set 1 | camacha
# Processing Record 48 of Set 1 | saint george
# Processing Record 49 of Set 1 | krasnoselkup
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | medea
# Processing Record 2 of Set 2 | glubokoe
# City not found. Skipping...
# Processing Record 3 of Set 2 | oranjemund
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | zhezkazgan
# Processing Record 8 of Set 2 | mana
# Processing Record 9 of Set 2 | pangnirtung
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | vylok
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | henties bay
# Processing Record 16 of Set 2 | iaciara
# Processing Record 17 of Set 2 | veselynove
# Processing Record 18 of Set 2 | ambilobe
# Processing Record 19 of Set 2 | rawah
# Processing Record 20 of Set 2 | lubumbashi
# Processing Record 21 of Set 2 | vila velha
# Processing Record 22 of Set 2 | harper
# Processing Record 23 of Set 2 | marathon
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | navahrudak
# Processing Record 26 of Set 2 | coquimbo
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | sao francisco
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | trikala
# Processing Record 31 of Set 2 | hispania
# Processing Record 32 of Set 2 | upata
# Processing Record 33 of Set 2 | burica
# City not found. Skipping...
# Processing Record 34 of Set 2 | hambantota
# Processing Record 35 of Set 2 | wilmington
# Processing Record 36 of Set 2 | rincon
# Processing Record 37 of Set 2 | makurdi
# Processing Record 38 of Set 2 | liverpool
# Processing Record 39 of Set 2 | mercedes
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | maniitsoq
# Processing Record 42 of Set 2 | umm kaddadah
# Processing Record 43 of Set 2 | plettenberg bay
# Processing Record 44 of Set 2 | diffa
# Processing Record 45 of Set 2 | requena
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | comodoro rivadavia
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | omboue
# Processing Record 50 of Set 2 | altoona
# Processing Record 1 of Set 3 | bilma
# Processing Record 2 of Set 3 | cabedelo
# Processing Record 3 of Set 3 | parabel
# Processing Record 4 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 3 | mehamn
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | antalaha
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | mahebourg
# Processing Record 10 of Set 3 | banda aceh
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | nalut
# Processing Record 15 of Set 3 | saint-francois
# Processing Record 16 of Set 3 | kruisfontein
# Processing Record 17 of Set 3 | mango
# Processing Record 18 of Set 3 | sumbe
# Processing Record 19 of Set 3 | umm lajj
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | itarema
# Processing Record 22 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 3 | boddam
# Processing Record 24 of Set 3 | elliot
# Processing Record 25 of Set 3 | faya
# Processing Record 26 of Set 3 | urumqi
# Processing Record 27 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | souillac
# Processing Record 30 of Set 3 | grindavik
# Processing Record 31 of Set 3 | niquelandia
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | tambura
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | monze
# Processing Record 37 of Set 3 | sanandaj
# Processing Record 38 of Set 3 | bafoulabe
# Processing Record 39 of Set 3 | porto nacional
# Processing Record 40 of Set 3 | paita
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | nicholasville
# Processing Record 43 of Set 3 | rio grande
# Processing Record 44 of Set 3 | santa fe
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | aswan
# Processing Record 47 of Set 3 | nadym
# Processing Record 48 of Set 3 | misratah
# Processing Record 49 of Set 3 | vestmanna
# Processing Record 50 of Set 3 | podor
# Processing Record 1 of Set 4 | turukhansk
# Processing Record 2 of Set 4 | lixourion
# Processing Record 3 of Set 4 | imbituba
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | tetouan
# Processing Record 6 of Set 4 | angoche
# Processing Record 7 of Set 4 | sao miguel do araguaia
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | sao gabriel da cachoeira
# Processing Record 10 of Set 4 | dumka
# Processing Record 11 of Set 4 | cuamba
# Processing Record 12 of Set 4 | pimenta bueno
# Processing Record 13 of Set 4 | kayerkan
# Processing Record 14 of Set 4 | americus
# Processing Record 15 of Set 4 | kashi
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | kuito
# Processing Record 18 of Set 4 | sarlat-la-caneda
# Processing Record 19 of Set 4 | donskoye
# Processing Record 20 of Set 4 | salinopolis
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | kavaratti
# Processing Record 23 of Set 4 | olinda
# Processing Record 24 of Set 4 | bonthe
# Processing Record 25 of Set 4 | beloha
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | nowy dwor gdanski
# Processing Record 28 of Set 4 | road town
# Processing Record 29 of Set 4 | mizdah
# Processing Record 30 of Set 4 | boras
# Processing Record 31 of Set 4 | baragua
# Processing Record 32 of Set 4 | mitsamiouli
# Processing Record 33 of Set 4 | manta
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | lerwick
# Processing Record 36 of Set 4 | plymouth
# Processing Record 37 of Set 4 | yenagoa
# Processing Record 38 of Set 4 | danielskuil
# Processing Record 39 of Set 4 | mangrol
# Processing Record 40 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | salalah
# Processing Record 43 of Set 4 | darab
# Processing Record 44 of Set 4 | tacuarembo
# Processing Record 45 of Set 4 | vestmannaeyjar
# Processing Record 46 of Set 4 | shelburne
# Processing Record 47 of Set 4 | meulaboh
# Processing Record 48 of Set 4 | cravo norte
# Processing Record 49 of Set 4 | siavonga
# Processing Record 50 of Set 4 | bengkulu
# Processing Record 1 of Set 5 | saint-pierre
# Processing Record 2 of Set 5 | rio gallegos
# Processing Record 3 of Set 5 | caxias
# Processing Record 4 of Set 5 | carepa
# Processing Record 5 of Set 5 | tucuman
# Processing Record 6 of Set 5 | constitucion
# Processing Record 7 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 5 | alakurtti
# Processing Record 9 of Set 5 | rawson
# Processing Record 10 of Set 5 | richards bay
# Processing Record 11 of Set 5 | acajutla
# Processing Record 12 of Set 5 | america dourada
# Processing Record 13 of Set 5 | songadh
# Processing Record 14 of Set 5 | kargat
# Processing Record 15 of Set 5 | pushkinskiye gory
# Processing Record 16 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 5 | tukrah
# Processing Record 18 of Set 5 | beberibe
# Processing Record 19 of Set 5 | los llanos de aridane
# Processing Record 20 of Set 5 | conceicao do araguaia
# Processing Record 21 of Set 5 | kibala
# Processing Record 22 of Set 5 | borisoglebskiy
# Processing Record 23 of Set 5 | asyut
# Processing Record 24 of Set 5 | camana
# Processing Record 25 of Set 5 | olhao
# Processing Record 26 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 5 | ugoofaaru
# Processing Record 28 of Set 5 | marawi
# Processing Record 29 of Set 5 | maloy
# Processing Record 30 of Set 5 | dzilam gonzalez
# Processing Record 31 of Set 5 | manbij
# Processing Record 32 of Set 5 | sesheke
# Processing Record 33 of Set 5 | pribelskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | bandipur
# Processing Record 35 of Set 5 | inhambane
# Processing Record 36 of Set 5 | gulfport
# Processing Record 37 of Set 5 | ziarat
# Processing Record 38 of Set 5 | decatur
# Processing Record 39 of Set 5 | knysna
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | iquique
# Processing Record 42 of Set 5 | matagami
# Processing Record 43 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 5 | zambezi
# Processing Record 45 of Set 5 | alto araguaia
# Processing Record 46 of Set 5 | la ligua
# Processing Record 47 of Set 5 | saint anthony
# Processing Record 48 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 49 of Set 5 | turayf
# Processing Record 50 of Set 5 | komsomolskiy
# Processing Record 1 of Set 6 | keti bandar
# Processing Record 2 of Set 6 | mashhad
# Processing Record 3 of Set 6 | sorland
# Processing Record 4 of Set 6 | bambous virieux
# Processing Record 5 of Set 6 | bure
# Processing Record 6 of Set 6 | burgersdorp
# Processing Record 7 of Set 6 | chake chake
# Processing Record 8 of Set 6 | kaspiyskiy
# Processing Record 9 of Set 6 | santa maria
# Processing Record 10 of Set 6 | yarmouth
# Processing Record 11 of Set 6 | hillsborough
# Processing Record 12 of Set 6 | dhidhdhoo
# Processing Record 13 of Set 6 | mahanoro
# Processing Record 14 of Set 6 | arlit
# Processing Record 15 of Set 6 | moussoro
# Processing Record 16 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 6 | rabak
# Processing Record 18 of Set 6 | porto novo
# Processing Record 19 of Set 6 | visby
# Processing Record 20 of Set 6 | navrongo
# Processing Record 21 of Set 6 | boa vista
# Processing Record 22 of Set 6 | sladkovo
# Processing Record 23 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | taoudenni
# Processing Record 26 of Set 6 | westport
# Processing Record 27 of Set 6 | morrinhos
# Processing Record 28 of Set 6 | borovoy
# Processing Record 29 of Set 6 | vysha
# Processing Record 30 of Set 6 | rebrikha
# Processing Record 31 of Set 6 | gigant
# Processing Record 32 of Set 6 | talara
# Processing Record 33 of Set 6 | tanout
# Processing Record 34 of Set 6 | bubaque
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | verkhnyaya inta
# Processing Record 37 of Set 6 | utete
# Processing Record 38 of Set 6 | belmonte
# Processing Record 39 of Set 6 | veraval
# Processing Record 40 of Set 6 | kjopsvik
# Processing Record 41 of Set 6 | grand gaube
# Processing Record 42 of Set 6 | fria
# Processing Record 43 of Set 6 | klaksvik
# Processing Record 44 of Set 6 | mabaruma
# Processing Record 45 of Set 6 | corinto
# Processing Record 46 of Set 6 | mayumba
# Processing Record 47 of Set 6 | colares
# Processing Record 48 of Set 6 | barquisimeto
# Processing Record 49 of Set 6 | shahreza
# Processing Record 50 of Set 6 | kattivakkam
# Processing Record 1 of Set 7 | goldap
# Processing Record 2 of Set 7 | sault sainte marie
# Processing Record 3 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 4 of Set 7 | urucara
# Processing Record 5 of Set 7 | acarau
# Processing Record 6 of Set 7 | urengoy
# Processing Record 7 of Set 7 | itaueira
# Processing Record 8 of Set 7 | la plata
# Processing Record 9 of Set 7 | ostrovnoy
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | holeby
# Processing Record 12 of Set 7 | quballat
# Processing Record 13 of Set 7 | palaikastron
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | vila franca do campo
# Processing Record 16 of Set 7 | juba
# Processing Record 17 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 7 | aksay
# Processing Record 19 of Set 7 | bridlington
# Processing Record 20 of Set 7 | skibbereen
# Processing Record 21 of Set 7 | eyl
# Processing Record 22 of Set 7 | sarakhs
# Processing Record 23 of Set 7 | goderich
# Processing Record 24 of Set 7 | kabare
# Processing Record 25 of Set 7 | oksfjord
# Processing Record 26 of Set 7 | savannah bight
# Processing Record 27 of Set 7 | hofn
# Processing Record 28 of Set 7 | jumla
# Processing Record 29 of Set 7 | thinadhoo
# Processing Record 30 of Set 7 | palora
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | sao jose da coroa grande
# Processing Record 33 of Set 7 | abha
# Processing Record 34 of Set 7 | saint-joseph
# Processing Record 35 of Set 7 | deder
# Processing Record 36 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | zmeinogorsk
# Processing Record 39 of Set 7 | jabinyanah
# Processing Record 40 of Set 7 | morant bay
# Processing Record 41 of Set 7 | rundu
# Processing Record 42 of Set 7 | udimskiy
# Processing Record 43 of Set 7 | buraydah
# Processing Record 44 of Set 7 | pindi gheb
# Processing Record 45 of Set 7 | naron
# Processing Record 46 of Set 7 | guantanamo
# Processing Record 47 of Set 7 | hargeysa
# Processing Record 48 of Set 7 | kissamos
# Processing Record 49 of Set 7 | porto velho
# Processing Record 50 of Set 7 | plouzane
# Processing Record 1 of Set 8 | mazamari
# Processing Record 2 of Set 8 | vardo
# Processing Record 3 of Set 8 | bathsheba
# Processing Record 4 of Set 8 | kabale
# Processing Record 5 of Set 8 | mahibadhoo
# Processing Record 6 of Set 8 | fonte boa
# Processing Record 7 of Set 8 | ayorou
# Processing Record 8 of Set 8 | tocopilla
# Processing Record 9 of Set 8 | red bank
# Processing Record 10 of Set 8 | kemijarvi
# Processing Record 11 of Set 8 | yavatmal
# Processing Record 12 of Set 8 | neuquen
# Processing Record 13 of Set 8 | maldonado
# Processing Record 14 of Set 8 | penzance
# Processing Record 15 of Set 8 | baft
# Processing Record 16 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 8 | fayetteville
# Processing Record 19 of Set 8 | jiwani
# Processing Record 20 of Set 8 | zaysan
# Processing Record 21 of Set 8 | portmore
# Processing Record 22 of Set 8 | bara
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | ondjiva
# Processing Record 25 of Set 8 | meiganga
# Processing Record 26 of Set 8 | kiruna
# Processing Record 27 of Set 8 | corbelia
# Processing Record 28 of Set 8 | groningen
# Processing Record 29 of Set 8 | eisenhuttenstadt
# City not found. Skipping...
# Processing Record 30 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 8 | belyy yar
# Processing Record 33 of Set 8 | praia
# Processing Record 34 of Set 8 | belogorsk
# Processing Record 35 of Set 8 | libertador general san martin
# Processing Record 36 of Set 8 | piney green
# Processing Record 37 of Set 8 | sannat
# Processing Record 38 of Set 8 | moyobamba
# Processing Record 39 of Set 8 | mbini
# Processing Record 40 of Set 8 | berlevag
# Processing Record 41 of Set 8 | montigny-en-gohelle
# Processing Record 42 of Set 8 | shubarkuduk
# Processing Record 43 of Set 8 | geraldton
# Processing Record 44 of Set 8 | pallasovka
# Processing Record 45 of Set 8 | balkhash
# Processing Record 46 of Set 8 | saldanha
# Processing Record 47 of Set 8 | nurota
# Processing Record 48 of Set 8 | ampanihy
# Processing Record 49 of Set 8 | tondi
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | nicoya
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | tanem
# Processing Record 4 of Set 9 | bonavista
# Processing Record 5 of Set 9 | khash
# Processing Record 6 of Set 9 | les cayes
# Processing Record 7 of Set 9 | aden
# Processing Record 8 of Set 9 | joshimath
# Processing Record 9 of Set 9 | pokhara
# Processing Record 10 of Set 9 | kita
# Processing Record 11 of Set 9 | troy
# Processing Record 12 of Set 9 | vilanova del cami
# Processing Record 13 of Set 9 | straumen
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | korla
# Processing Record 16 of Set 9 | punta de piedra
# Processing Record 17 of Set 9 | gazanjyk
# Processing Record 18 of Set 9 | lethem
# Processing Record 19 of Set 9 | rio bueno
# Processing Record 20 of Set 9 | bafata
# Processing Record 21 of Set 9 | vilcun
# Processing Record 22 of Set 9 | palmas bellas
# Processing Record 23 of Set 9 | aiken
# Processing Record 24 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 26 of Set 9 | jaca
# Processing Record 27 of Set 9 | sakakah
# Processing Record 28 of Set 9 | calabar
# Processing Record 29 of Set 9 | balykshi
# Processing Record 30 of Set 9 | toamasina
# Processing Record 31 of Set 9 | sinnamary
# Processing Record 32 of Set 9 | port-gentil
# Processing Record 33 of Set 9 | kuva
# City not found. Skipping...
# Processing Record 34 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 9 | darovskoy
# Processing Record 36 of Set 9 | huarmey
# Processing Record 37 of Set 9 | baghmara
# Processing Record 38 of Set 9 | umarkot
# Processing Record 39 of Set 9 | manaure
# Processing Record 40 of Set 9 | quatre cocos
# Processing Record 41 of Set 9 | malinyi
# Processing Record 42 of Set 9 | plougastel-daoulas
# Processing Record 43 of Set 9 | weligama
# Processing Record 44 of Set 9 | domoni
# Processing Record 45 of Set 9 | makueni
# Processing Record 46 of Set 9 | manga
# Processing Record 47 of Set 9 | kuusamo
# Processing Record 48 of Set 9 | staryy krym
# Processing Record 49 of Set 9 | loyga
# Processing Record 50 of Set 9 | hukuntsi
# Processing Record 1 of Set 10 | tierralta
# Processing Record 2 of Set 10 | anamur
# Processing Record 3 of Set 10 | zharkent
# Processing Record 4 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 10 | abu dhabi
# Processing Record 6 of Set 10 | kangaatsiaq
# Processing Record 7 of Set 10 | qandala
# Processing Record 8 of Set 10 | lighthouse point
# Processing Record 9 of Set 10 | karaton
# Processing Record 10 of Set 10 | boksitogorsk
# Processing Record 11 of Set 10 | atlantic city
# Processing Record 12 of Set 10 | urucurituba
# Processing Record 13 of Set 10 | acari
# Processing Record 14 of Set 10 | talesh
# City not found. Skipping...
# Processing Record 15 of Set 10 | caravelas
# Processing Record 16 of Set 10 | vammala
# Processing Record 17 of Set 10 | gummidipundi
# Processing Record 18 of Set 10 | petrokamenskoye
# Processing Record 19 of Set 10 | artyom
# Processing Record 20 of Set 10 | itapipoca
# Processing Record 21 of Set 10 | manyana
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | kumluca
# Processing Record 24 of Set 10 | matara
# Processing Record 25 of Set 10 | najran
# Processing Record 26 of Set 10 | monchegorsk
# Processing Record 27 of Set 10 | awjilah
# Processing Record 28 of Set 10 | altyn-topkan
# Processing Record 29 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 30 of Set 10 | upington
# Processing Record 31 of Set 10 | kasongo
# Processing Record 32 of Set 10 | quiindy
# Processing Record 33 of Set 10 | cervo
# Processing Record 34 of Set 10 | dingle
# Processing Record 35 of Set 10 | odlabari
# Processing Record 36 of Set 10 | villa maria
# Processing Record 37 of Set 10 | puerto narino
# Processing Record 38 of Set 10 | opuwo
# Processing Record 39 of Set 10 | mwinilunga
# Processing Record 40 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 10 | santo domingo
# Processing Record 42 of Set 10 | ravar
# Processing Record 43 of Set 10 | kinshasa
# Processing Record 44 of Set 10 | avanigadda
# Processing Record 45 of Set 10 | bajah
# Processing Record 46 of Set 10 | chintamani
# Processing Record 47 of Set 10 | talcahuano
# Processing Record 48 of Set 10 | bani
# Processing Record 49 of Set 10 | taltal
# Processing Record 50 of Set 10 | matameye
# City not found. Skipping...
# Processing Record 1 of Set 11 | besancon
# Processing Record 2 of Set 11 | sao joao da barra
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | puerto cabezas
# Processing Record 5 of Set 11 | dosso
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | blagoyevo
# Processing Record 8 of Set 11 | saint-augustin
# Processing Record 9 of Set 11 | hobyo
# Processing Record 10 of Set 11 | rehoboth
# Processing Record 11 of Set 11 | sainte-savine
# Processing Record 12 of Set 11 | yomou
# Processing Record 13 of Set 11 | riyadh
# Processing Record 14 of Set 11 | nanticoke
# Processing Record 15 of Set 11 | biltine
# Processing Record 16 of Set 11 | san joaquin
# Processing Record 17 of Set 11 | hato mayor
# Processing Record 18 of Set 11 | kargil
# Processing Record 19 of Set 11 | montepuez
# Processing Record 20 of Set 11 | naryan-mar
# Processing Record 21 of Set 11 | calama
# Processing Record 22 of Set 11 | ketchenery
# City not found. Skipping...
# Processing Record 23 of Set 11 | mopti
# Processing Record 24 of Set 11 | senneterre
# Processing Record 25 of Set 11 | myski
# Processing Record 26 of Set 11 | didwana
# Processing Record 27 of Set 11 | porbandar
# Processing Record 28 of Set 11 | businga
# Processing Record 29 of Set 11 | mezen
# Processing Record 30 of Set 11 | caxito
# Processing Record 31 of Set 11 | bursol
# City not found. Skipping...
# Processing Record 32 of Set 11 | lagoa
# Processing Record 33 of Set 11 | goma
# Processing Record 34 of Set 11 | montana
# Processing Record 35 of Set 11 | qasigiannguit
# Processing Record 36 of Set 11 | jever
# Processing Record 37 of Set 11 | tarut
# Processing Record 38 of Set 11 | boueni
# Processing Record 39 of Set 11 | birao
# Processing Record 40 of Set 11 | maarianhamina
# Processing Record 41 of Set 11 | belis
# Processing Record 42 of Set 11 | kondinskoye
# Processing Record 43 of Set 11 | gat
# Processing Record 44 of Set 11 | albany
# Processing Record 45 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 11 | utica
# Processing Record 47 of Set 11 | bogo
# Processing Record 48 of Set 11 | valdemarpils
# Processing Record 49 of Set 11 | pangody
# Processing Record 50 of Set 11 | peniche
# Processing Record 1 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | makokou
# Processing Record 3 of Set 12 | ambatondrazaka
# Processing Record 4 of Set 12 | havre-saint-pierre
# Processing Record 5 of Set 12 | chapais
# Processing Record 6 of Set 12 | dalbandin
# Processing Record 7 of Set 12 | stornoway
# Processing Record 8 of Set 12 | rosario
# Processing Record 9 of Set 12 | hatillo
# Processing Record 10 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 12 | soltsy
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | venado tuerto
# Processing Record 14 of Set 12 | les herbiers
# Processing Record 15 of Set 12 | kernersville
# Processing Record 16 of Set 12 | blacksburg
# Processing Record 17 of Set 12 | galchino
# City not found. Skipping...
# Processing Record 18 of Set 12 | gornopravdinsk
# Processing Record 19 of Set 12 | kissidougou
# Processing Record 20 of Set 12 | mbengwi
# Processing Record 21 of Set 12 | atbasar
# Processing Record 22 of Set 12 | solvychegodsk
# Processing Record 23 of Set 12 | villarrica
# Processing Record 24 of Set 12 | muros
# Processing Record 25 of Set 12 | karasjok
# Processing Record 26 of Set 12 | ola
# Processing Record 27 of Set 12 | banes
# Processing Record 28 of Set 12 | estelle
# Processing Record 29 of Set 12 | springfield
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | mitu
# Processing Record 32 of Set 12 | onguday
# Processing Record 33 of Set 12 | miandoab
# Processing Record 34 of Set 12 | sikasso
# Processing Record 35 of Set 12 | carutapera
# Processing Record 36 of Set 12 | rudsar
# Processing Record 37 of Set 12 | morondava
# Processing Record 38 of Set 12 | garowe
# Processing Record 39 of Set 12 | oistins
# Processing Record 40 of Set 12 | antofagasta
# Processing Record 41 of Set 12 | krasnoshchekovo
# Processing Record 42 of Set 12 | scarborough
# Processing Record 43 of Set 12 | tessalit
# Processing Record 44 of Set 12 | hajnowka
# Processing Record 45 of Set 12 | viedma
# Processing Record 46 of Set 12 | florianopolis
# Processing Record 47 of Set 12 | pampas
# Processing Record 48 of Set 12 | thatta
# Processing Record 49 of Set 12 | dogondoutchi
# Processing Record 50 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 1 of Set 13 | ler
# Processing Record 2 of Set 13 | rorvik
# Processing Record 3 of Set 13 | pitimbu
# Processing Record 4 of Set 13 | istria
# Processing Record 5 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 13 | maiduguri
# Processing Record 7 of Set 13 | surt
# Processing Record 8 of Set 13 | maicao
# Processing Record 9 of Set 13 | boden
# Processing Record 10 of Set 13 | benguela
# Processing Record 11 of Set 13 | atocha
# Processing Record 12 of Set 13 | honningsvag
# Processing Record 13 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 13 | novouzensk
# Processing Record 15 of Set 13 | veydelevka
# Processing Record 16 of Set 13 | luena
# Processing Record 17 of Set 13 | onega
# Processing Record 18 of Set 13 | chitipa
# Processing Record 19 of Set 13 | teguise
# Processing Record 20 of Set 13 | uzumlu
# City not found. Skipping...
# Processing Record 21 of Set 13 | santa cruz
# Processing Record 22 of Set 13 | takoradi
# Processing Record 23 of Set 13 | tambacounda
# Processing Record 24 of Set 13 | waw
# Processing Record 25 of Set 13 | punta cardon
# Processing Record 26 of Set 13 | kalengwa
# Processing Record 27 of Set 13 | skelleftea
# Processing Record 28 of Set 13 | bunol
# Processing Record 29 of Set 13 | paamiut
# Processing Record 30 of Set 13 | tamworth
# Processing Record 31 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 32 of Set 13 | pontes e lacerda
# Processing Record 33 of Set 13 | killybegs
# Processing Record 34 of Set 13 | gorom-gorom
# Processing Record 35 of Set 13 | uarini
# Processing Record 36 of Set 13 | maradi
# Processing Record 37 of Set 13 | louisville
# Processing Record 38 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 13 | oromocto
# Processing Record 40 of Set 13 | bardiyah
# Processing Record 41 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 13 | sovetskiy
# Processing Record 43 of Set 13 | kurchum
# Processing Record 44 of Set 13 | slavonski brod
# Processing Record 45 of Set 13 | ginir
# Processing Record 46 of Set 13 | zonguldak
# Processing Record 47 of Set 13 | marsh harbour
# Processing Record 48 of Set 13 | waddan
# Processing Record 49 of Set 13 | vila do maio
# Processing Record 50 of Set 13 | koslan
# Processing Record 1 of Set 14 | general roca
# Processing Record 2 of Set 14 | pocone
# Processing Record 3 of Set 14 | abnub
# Processing Record 4 of Set 14 | qaqortoq
# Processing Record 5 of Set 14 | statesville
# Processing Record 6 of Set 14 | viseu
# Processing Record 7 of Set 14 | shepsi
# Processing Record 8 of Set 14 | kilembe
# Processing Record 9 of Set 14 | san andres
# Processing Record 10 of Set 14 | quelimane
# Processing Record 11 of Set 14 | urucui
# Processing Record 12 of Set 14 | bam
# Processing Record 13 of Set 14 | desbiens
# Processing Record 14 of Set 14 | hammerfest
# Processing Record 15 of Set 14 | murygino
# Processing Record 16 of Set 14 | chakrata
# Processing Record 17 of Set 14 | moba
# Processing Record 18 of Set 14 | santa rosa
# Processing Record 19 of Set 14 | puerto madryn
# Processing Record 20 of Set 14 | sokna
# Processing Record 21 of Set 14 | tifton
# Processing Record 22 of Set 14 | novorzhev
# Processing Record 23 of Set 14 | bhawanipatna
# Processing Record 24 of Set 14 | inongo
# Processing Record 25 of Set 14 | jardim do serido
# Processing Record 26 of Set 14 | gamba
# Processing Record 27 of Set 14 | awbari
# Processing Record 28 of Set 14 | port blair
# Processing Record 29 of Set 14 | alice town
# Processing Record 30 of Set 14 | saray
# Processing Record 31 of Set 14 | evansville
# Processing Record 32 of Set 14 | yemtsa
# Processing Record 33 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 14 | monrovia
# Processing Record 35 of Set 14 | vigrestad
# Processing Record 36 of Set 14 | araguacu
# Processing Record 37 of Set 14 | axim
# Processing Record 38 of Set 14 | harindanga
# Processing Record 39 of Set 14 | wundanyi
# Processing Record 40 of Set 14 | zapolyarnyy
# Processing Record 41 of Set 14 | birzai
# Processing Record 42 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 14 | firozpur
# Processing Record 44 of Set 14 | ufa
# Processing Record 45 of Set 14 | tahoua
# Processing Record 46 of Set 14 | mbulu
# Processing Record 47 of Set 14 | kristiinankaupunki
# Processing Record 48 of Set 14 | pavlovskiy
# Processing Record 49 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 14 | itapirapua
# Processing Record 1 of Set 15 | jimma
# Processing Record 2 of Set 15 | tabou
# Processing Record 3 of Set 15 | fomboni
# Processing Record 4 of Set 15 | normandin
# Processing Record 5 of Set 15 | irituia
# Processing Record 6 of Set 15 | cap malheureux
# Processing Record 7 of Set 15 | spassk
# Processing Record 8 of Set 15 | hesla
# Processing Record 9 of Set 15 | chipata
# Processing Record 10 of Set 15 | sur
# Processing Record 11 of Set 15 | barra do corda
# Processing Record 12 of Set 15 | araouane
# Processing Record 13 of Set 15 | natal
# Processing Record 14 of Set 15 | pasni
# Processing Record 15 of Set 15 | astorga
# Processing Record 16 of Set 15 | esplanada
# Processing Record 17 of Set 15 | bull savanna
# Processing Record 18 of Set 15 | etampes
# Processing Record 19 of Set 15 | vyazma
# Processing Record 20 of Set 15 | letterkenny
# Processing Record 21 of Set 15 | nosy varika
# Processing Record 22 of Set 15 | lima
# Processing Record 23 of Set 15 | burgeo
# Processing Record 24 of Set 15 | lyubeshiv
# City not found. Skipping...
# Processing Record 25 of Set 15 | pemba
# Processing Record 26 of Set 15 | conceicao da barra
# Processing Record 27 of Set 15 | qrendi
# Processing Record 28 of Set 15 | sebring
# Processing Record 29 of Set 15 | gubskaya
# Processing Record 30 of Set 15 | changji
# Processing Record 31 of Set 15 | lydenburg
# Processing Record 32 of Set 15 | kardla
# Processing Record 33 of Set 15 | port hawkesbury
# Processing Record 34 of Set 15 | zasheyek
# Processing Record 35 of Set 15 | narimanov
# Processing Record 36 of Set 15 | pascagoula
# Processing Record 37 of Set 15 | carballo
# Processing Record 38 of Set 15 | augustow
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tiruvalla   9.3833  76.5667     74.03        94          98
# 1       Bredasdorp -34.5322  20.0403     64.40        74          13
# 2             Jalu  29.0331  21.5482     58.71        50           0
# 3  Teodoro Sampaio -22.5325 -52.1675     72.73        63          76
# 4       Bjornevatn  69.6672  29.9847     35.22        80          75
# 5        Hithadhoo  -0.6000  73.0833     81.12        74          99
# 6           Visnes  59.3556   5.2242     45.21        75         100
# 7            Qeshm  26.9581  56.2719     73.29        64          51
# 8         Maragheh  37.3917  46.2398     41.27        87          75
# 9   Port Elizabeth -33.9180  25.5701     70.32        81           0
#
#    Wind Speed Country Current Description                 Date
# 0        2.51      IN     overcast clouds  2022-11-30 00:22:17
# 1        3.96      ZA          few clouds  2022-11-30 00:22:18
# 2        8.25      LY           clear sky  2022-11-30 00:22:18
# 3        7.36      BR       broken clouds  2022-11-30 00:22:19
# 4       17.27      NO       broken clouds  2022-11-30 00:22:19
# 5        7.56      MV     overcast clouds  2022-11-30 00:22:20
# 6        6.91      NO     overcast clouds  2022-11-30 00:22:20
# 7        7.16      IR       broken clouds  2022-11-30 00:22:21
# 8        2.30      IR                mist  2022-11-30 00:22:21
# 9       17.27      ZA           clear sky  2022-11-30 00:21:05

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ["City", "Country", "Date", "Lat", "Lng",
                    "Max Temp", "Humidity", "Cloudiness",
                    "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#               City Country                 Date      Lat      Lng  Max Temp  \
# 0        Tiruvalla      IN  2022-11-30 00:22:17   9.3833  76.5667     74.03
# 1       Bredasdorp      ZA  2022-11-30 00:22:18 -34.5322  20.0403     64.40
# 2             Jalu      LY  2022-11-30 00:22:18  29.0331  21.5482     58.71
# 3  Teodoro Sampaio      BR  2022-11-30 00:22:19 -22.5325 -52.1675     72.73
# 4       Bjornevatn      NO  2022-11-30 00:22:19  69.6672  29.9847     35.22
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        94          98        2.51     overcast clouds
# 1        74          13        3.96          few clouds
# 2        50           0        8.25           clear sky
# 3        63          76        7.36       broken clouds
# 4        80          75       17.27       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City ID")
